# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejal221293/Deep-Learning/blob/main/Multiclass_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Binary Classifcation with Keras

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from warnings import filterwarnings
filterwarnings("ignore")
